# %% [markdown]
# ### WeatherPy
# ----
#
# #### This analysis will use Python scripting to visualize the weather of 600+ cities around the world with varying distances from the equator. The script will make external calls to the OpenWeatherMap API.
#
# ### Outcomes: Build a series of visualizations (scatter plots) to show the following relationships:
#
#    ####    Temperature (F) vs. Latitude
#    ####    Humidity (%) vs. Latitude
#    ####    Cloudiness (%) vs. Latitude
#    ####    Wind Speed (mph) vs. Latitude
#
# ### Framework :
#
#   ####    Python Requests
#   ####    APIs
#   ###    JSON Traversals
#
# ### Analysis:
#
# #### The weather becomes significantly warmer the closer we get to the equator (0 Degrees Latitude). On 4/13/2020, the southern hemisphere tends to be warmer than the northern hemisphere.
#
#
# #### Humidity in cities within a range of +/- 19 degrees of the equator appear to be consistently more humid. That said, the relationship between Latitude and Humidity is weak. High and Low humidity appear randomly in both hemispheres outside of the +/- 19 degree range.
#
#
# #### There is no strong relationship between latitude and cloudiness.
#
#
# #### There is no strong relationship between latitude and wind speed. However, in the northern hemisphere, there are a few cities that have above average (20 mph) windspeeds.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
#print (weather_api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#cities
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#OpenWeather API URL...
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# set up the query URL and make the request
weatherAPI_url = url + "appid=" + weather_api_key + "&units=" + units + "&q="
weatherAPI_response = requests.get(weatherAPI_url + cities[2])
#if weatherAPI_response.status_code == 200:
#    print("yes")

print("Beginning Data Retrival")
print("------------------------------")
group_counter = 1
rec_counter = 1

weather_data = {"City":[],"Lat":[],"Lng":[],"Max Temp":[],"Humidity":[],"Cloudiness":[],
                "Wind Speed":[],"Country":[],"Date":[]}

for city in cities:
    weatherAPI_response = requests.get(weatherAPI_url + city)
    weatherAPI_response_json = weatherAPI_response.json()
    
    if weatherAPI_response.status_code == 200:
        weather_data["City"].append(city)
        weather_data["Cloudiness"].append(weatherAPI_response_json['clouds']['all'])
        weather_data["Country"].append(weatherAPI_response_json['sys']['country'])
        weather_data["Date"].append(weatherAPI_response_json['dt'])
        weather_data["Humidity"].append(weatherAPI_response_json['main']['humidity'])
        weather_data["Lat"].append(weatherAPI_response_json['coord']['lat'])
        weather_data["Lng"].append(weatherAPI_response_json['coord']['lon'])
        weather_data["Max Temp"].append(weatherAPI_response_json['main']['temp_max'])
        weather_data["Wind Speed"].append(weatherAPI_response_json['wind']['speed'])
        if rec_counter <= 50:
            print(f"Processing Record {rec_counter} of Set {group_counter} | {city}")
            rec_counter += 1 
        else:
            rec_counter = 0
            group_counter += 1
            print(f"Processing Record {rec_counter} of Set {group_counter} | {city}")
            rec_counter += 1
    else:
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrival
# ------------------------------
# Processing Record 1 of Set 1 | rocha
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | ormara
# City not found. Skipping...
# Processing Record 5 of Set 1 | sao joao da barra
# Processing Record 6 of Set 1 | aklavik
# Processing Record 7 of Set 1 | srednekolymsk
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 10 of Set 1 | zabol
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | manggar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | egvekinot
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | mackay
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | kimparana
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | kiunga
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | tazovskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | esperance
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | juba
# Processing Record 35 of Set 1 | adrar
# Processing Record 36 of Set 1 | eureka
# Processing Record 37 of Set 1 | detva
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | eyl
# Processing Record 40 of Set 1 | tabou
# Processing Record 41 of Set 1 | praya
# Processing Record 42 of Set 1 | pangnirtung
# Processing Record 43 of Set 1 | kalmunai
# Processing Record 44 of Set 1 | gao
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | kaili
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | te anau
# Processing Record 0 of Set 2 | bedi
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | glendive
# City not found. Skipping...
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | fenoarivo
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | salvador
# Processing Record 11 of Set 2 | port alberni
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | meulaboh
# Processing Record 14 of Set 2 | ode
# Processing Record 15 of Set 2 | mount gambier
# Processing Record 16 of Set 2 | la ronge
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | moose factory
# Processing Record 19 of Set 2 | dali
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | malim
# Processing Record 24 of Set 2 | port hardy
# Processing Record 25 of Set 2 | alice springs
# Processing Record 26 of Set 2 | vardo
# Processing Record 27 of Set 2 | redlands
# Processing Record 28 of Set 2 | mogadouro
# Processing Record 29 of Set 2 | dwarka
# Processing Record 30 of Set 2 | maniwaki
# Processing Record 31 of Set 2 | buala
# Processing Record 32 of Set 2 | mawlaik
# Processing Record 33 of Set 2 | mananjary
# Processing Record 4 of Set 4 | aboisso
# Processing Record 5 of Set 4 | kizema
# Processing Record 6 of Set 4 | katobu
# Processing Record 7 of Set 4 | wattegama
# City not found. Skipping...
# Processing Record 8 of Set 4 | xai-xai
# Processing Record 9 of Set 4 | mangrol
# Processing Record 10 of Set 4 | pedernales
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | saint-joseph
# Processing Record 13 of Set 4 | anadyr
# Processing Record 14 of Set 4 | toccoa
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | cartagena del chaira
# Processing Record 17 of Set 4 | hobyo
# Processing Record 18 of Set 4 | basco
# Processing Record 19 of Set 4 | san cristobal
# Processing Record 20 of Set 4 | cururupu
# Processing Record 21 of Set 4 | maumere
# Processing Record 22 of Set 4 | yar-sale
# Processing Record 23 of Set 4 | robertsport
# Processing Record 24 of Set 4 | zeya
# Processing Record 25 of Set 4 | athabasca
# Processing Record 26 of Set 4 | tholos
# Processing Record 27 of Set 4 | itarema
# Processing Record 28 of Set 4 | burns lake
# Processing Record 29 of Set 4 | coihaique
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | rivadavia
# Processing Record 32 of Set 4 | berberati
# Processing Record 33 of Set 4 | isangel
# Processing Record 34 of Set 4 | vitim
# Processing Record 35 of Set 4 | manicore
# Processing Record 36 of Set 4 | bridlington
# Processing Record 37 of Set 4 | santa ines
# Processing Record 38 of Set 4 | jinchang
# Processing Record 39 of Set 4 | port augusta
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | katherine
# Processing Record 42 of Set 4 | muscatine
# Processing Record 43 of Set 4 | hongjiang
# Processing Record 44 of Set 4 | liku
# City not found. Skipping...
# Processing Record 45 of Set 4 | port alfred
# Processing Record 46 of Set 4 | port moresby
# Processing Record 47 of Set 4 | hinton
# Processing Record 48 of Set 4 | mehamn
# Processing Record 49 of Set 4 | nsukka
# Processing Record 50 of Set 4 | lagoa
# Processing Record 0 of Set 5 | satis
# Processing Record 1 of Set 5 | bamora
# Processing Record 2 of Set 5 | lincoln
# Processing Record 3 of Set 5 | teahupoo
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | carbonia
# Processing Record 6 of Set 5 | gigmoto
# Processing Record 7 of Set 5 | nome
# Processing Record 8 of Set 5 | madras
# Processing Record 9 of Set 5 | ahipara
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | kalamare
# Processing Record 13 of Set 5 | freeport
# Processing Record 14 of Set 5 | linxia
# Processing Record 15 of Set 5 | turukhansk
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | palu
# Processing Record 18 of Set 5 | vestmanna
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | carnarvon
# Processing Record 21 of Set 5 | phan thiet
# Processing Record 22 of Set 5 | broome
# Processing Record 23 of Set 5 | gamba
# Processing Record 24 of Set 5 | george town
# Processing Record 25 of Set 5 | constitucion
# City not found. Skipping...
# Processing Record 26 of Set 5 | cairns
# Processing Record 27 of Set 5 | yaguachi
# Processing Record 28 of Set 5 | biak
# Processing Record 29 of Set 5 | kaseda
# Processing Record 30 of Set 5 | maitum
# Processing Record 31 of Set 5 | cimislia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 5 | kompaniyivka
# Processing Record 33 of Set 5 | pisco
# Processing Record 34 of Set 5 | hervey bay
# Processing Record 35 of Set 5 | pacific grove
# Processing Record 36 of Set 5 | araouane
# Processing Record 37 of Set 5 | camacha
# Processing Record 38 of Set 5 | broken hill
# Processing Record 39 of Set 5 | tautira
# Processing Record 40 of Set 5 | voznesenye
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | newport
# Processing Record 43 of Set 5 | huesca
# City not found. Skipping...
# Processing Record 44 of Set 5 | aykhal
# Processing Record 45 of Set 5 | xam nua
# Processing Record 46 of Set 5 | sanmenxia
# Processing Record 47 of Set 5 | bilma
# Processing Record 48 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 5 | limon
# Processing Record 50 of Set 5 | chandbali
# Processing Record 0 of Set 6 | atbasar
# Processing Record 1 of Set 6 | marsh harbour
# Processing Record 2 of Set 6 | trelew
# Processing Record 3 of Set 6 | san jose
# Processing Record 4 of Set 6 | tiksi
# Processing Record 5 of Set 6 | yuryevets
# Processing Record 6 of Set 6 | kununurra
# Processing Record 7 of Set 6 | ponta do sol
# Processing Record 8 of Set 6 | ahtopol
# Processing Record 9 of Set 6 | baffa
# Processing Record 10 of Set 6 | bengkulu
# Processing Record 11 of Set 6 | hudiksvall
# Processing Record 12 of Set 6 | wanaka
# Processing Record 13 of Set 6 | riyadh
# Processing Record 14 of Set 6 | tongchuan
# Processing Record 15 of Set 6 | udachnyy
# Processing Record 16 of Set 6 | kambove
# Processing Record 17 of Set 6 | kostolac
# Processing Record 18 of Set 6 | khandyga
# Processing Record 19 of Set 6 | tual
# Processing Record 20 of Set 6 | nagua
# Processing Record 21 of Set 6 | merauke
# Processing Record 22 of Set 6 | whitley bay
# Processing Record 23 of Set 6 | vanavara
# Processing Record 24 of Set 6 | jammal
# Processing Record 25 of Set 6 | neyshabur
# Processing Record 26 of Set 6 | raga
# Processing Record 27 of Set 6 | ratnagiri
# Processing Record 28 of Set 6 | hay river
# Processing Record 29 of Set 6 | norman wells
# Processing Record 30 of Set 6 | barras
# Processing Record 31 of Set 6 | nadym
# Processing Record 32 of Set 6 | mujiayingzi
# Processing Record 33 of Set 6 | jamsa
# Processing Record 34 of Set 6 | impfondo
# Processing Record 35 of Set 6 | sioux lookout
# Processing Record 36 of Set 6 | richards bay
# Processing Record 37 of Set 6 | randazzo
# Processing Record 38 of Set 6 | honningsvag
# Processing Record 39 of Set 6 | beringovskiy
# Processing Record 40 of Set 6 | antofagasta
# Processing Record 41 of Set 6 | cabugao
# Processing Record 42 of Set 6 | brewster
# Processing Record 43 of Set 6 | kruisfontein
# Processing Record 44 of Set 6 | rabat
# Processing Record 45 of Set 6 | saint-pierre
# Processing Record 46 of Set 6 | dikson
# Processing Record 47 of Set 6 | colares
# Processing Record 48 of Set 6 | edd
# Processing Record 49 of Set 6 | keti bandar
# City not found. Skipping...
# Processing Record 50 of Set 6 | acarau
# Processing Record 39 of Set 9 | mandan
# Processing Record 40 of Set 9 | san quintin
# Processing Record 41 of Set 9 | gutierrez
# Processing Record 42 of Set 9 | aja
# Processing Record 43 of Set 9 | zhanakorgan
# Processing Record 44 of Set 9 | luba
# Processing Record 45 of Set 9 | kuytun
# Processing Record 46 of Set 9 | ust-kut
# Processing Record 47 of Set 9 | klaksvik
# Processing Record 48 of Set 9 | champerico
# Processing Record 49 of Set 9 | altamont
# Processing Record 50 of Set 9 | englewood
# Processing Record 0 of Set 10 | yumen
# Processing Record 1 of Set 10 | caohai
# Processing Record 2 of Set 10 | monte santo de minas
# City not found. Skipping...
# Processing Record 3 of Set 10 | raudeberg
# Processing Record 4 of Set 10 | zapolyarnyy
# Processing Record 5 of Set 10 | sibut
# Processing Record 6 of Set 10 | marawi
# Processing Record 7 of Set 10 | grand island
# Processing Record 8 of Set 10 | luangwa
# Processing Record 9 of Set 10 | shingu
# Processing Record 10 of Set 10 | avera
# Processing Record 11 of Set 10 | knyaginino
# Processing Record 12 of Set 10 | vuktyl
# Processing Record 13 of Set 10 | la plata
# Processing Record 14 of Set 10 | qurbus
# Processing Record 15 of Set 10 | calvinia
# Processing Record 16 of Set 10 | ijui
# Processing Record 17 of Set 10 | lakatoro
# City not found. Skipping...
# Processing Record 18 of Set 10 | konya
# Processing Record 19 of Set 10 | katangli
# Processing Record 20 of Set 10 | hambantota
# Processing Record 21 of Set 10 | necochea
# Processing Record 22 of Set 10 | oksfjord
# Processing Record 23 of Set 10 | san pedro de macoris
# Processing Record 24 of Set 10 | lakes entrance
# Processing Record 25 of Set 10 | seddon
# Processing Record 26 of Set 10 | ola
# Processing Record 27 of Set 10 | meridian
# City not found. Skipping...
# Processing Record 28 of Set 10 | altamira
# Processing Record 29 of Set 10 | tura
# Processing Record 30 of Set 10 | minab
# Processing Record 31 of Set 10 | nyrob
# Processing Record 32 of Set 10 | nouadhibou
# Processing Record 33 of Set 10 | panjab
# Processing Record 34 of Set 10 | ardee
# City not found. Skipping...
# Processing Record 35 of Set 10 | los llanos de aridane
# Processing Record 36 of Set 10 | yashkul
# Processing Record 37 of Set 10 | kifri
# Processing Record 38 of Set 10 | poum
# Processing Record 39 of Set 10 | etchoropo
# Processing Record 40 of Set 10 | moratuwa
# Processing Record 41 of Set 10 | arroyo
# Processing Record 42 of Set 10 | kupang
# Processing Record 43 of Set 10 | camopi
# Processing Record 44 of Set 10 | talaya
# Processing Record 45 of Set 10 | acapulco
# Processing Record 46 of Set 10 | arica
# Processing Record 47 of Set 10 | vanimo
# Processing Record 48 of Set 10 | mae sot
# Processing Record 49 of Set 10 | lazaro cardenas
# Processing Record 50 of Set 10 | namibe
# City not found. Skipping...
# Processing Record 0 of Set 11 | shirokiy
# Processing Record 1 of Set 11 | vagur
# Processing Record 2 of Set 11 | sri aman
# City not found. Skipping...
# Processing Record 3 of Set 11 | grand gaube
# Processing Record 4 of Set 11 | olga
# Processing Record 5 of Set 11 | bestobe
# Processing Record 6 of Set 11 | lundazi
# Processing Record 7 of Set 11 | batagay-alyta
# Processing Record 8 of Set 11 | otacilio costa
# Processing Record 9 of Set 11 | troitsko-pechorsk
# Processing Record 10 of Set 11 | hualmay
# Processing Record 11 of Set 11 | kankon
# Processing Record 12 of Set 11 | ban nahin
# Processing Record 13 of Set 11 | havre-saint-pierre
# Processing Record 14 of Set 11 | nanortalik
# Processing Record 15 of Set 11 | yerofey pavlovich
# City not found. Skipping...
# Processing Record 16 of Set 11 | port shepstone
# Processing Record 17 of Set 11 | pavilosta
# Processing Record 18 of Set 11 | terra santa
# Processing Record 19 of Set 11 | kloulklubed
# Processing Record 20 of Set 11 | buraydah
# City not found. Skipping...
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | lasa
# Processing Record 23 of Set 11 | severo-yeniseyskiy
# Processing Record 24 of Set 11 | oistins
# Processing Record 25 of Set 11 | gravdal
# Processing Record 26 of Set 11 | baykit
# Processing Record 27 of Set 11 | mingshui
# City not found. Skipping...
# Processing Record 28 of Set 11 | narsaq
# Processing Record 29 of Set 11 | proddatur
# Processing Record 30 of Set 11 | mokobeng
# Processing Record 31 of Set 11 | ambilobe
# Processing Record 32 of Set 11 | madeji
# Processing Record 33 of Set 11 | safranbolu
# Processing Record 34 of Set 11 | uinskoye
# Processing Record 35 of Set 11 | mecca
# Processing Record 36 of Set 11 | karoi
# Processing Record 37 of Set 11 | mareeba
# Processing Record 38 of Set 11 | medea
# Processing Record 39 of Set 11 | vizinga
# Processing Record 40 of Set 11 | pokhara
# Processing Record 41 of Set 11 | mandalgovi
# Processing Record 42 of Set 11 | kahului
# Processing Record 43 of Set 11 | tocopilla
# City not found. Skipping...
# Processing Record 44 of Set 11 | carmarthen
# Processing Record 45 of Set 11 | requena
# Processing Record 46 of Set 11 | lichuan
# Processing Record 47 of Set 11 | amapa
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(weather_data)
weather_df.head()
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0              rocha -34.48  -54.33     56.98        91           0
# 1            rikitea -23.12 -134.97     77.36        63           1
# 2             avarua -21.21 -159.78     82.40        61          10
# 3             ormara  25.21   64.64     80.06        66           0
# 4  sao joao da barra -21.64  -41.05     72.48        83          96
#
#    Wind Speed Country        Date
# 0        4.68      UY  1587173925
# 1        1.99      PF  1587173875
# 2        6.93      CK  1587173654
# 3        5.57      PK  1587173926
# 4       11.12      BR  1587173926

# %%
# Exporting the city data into csv
weather_df.to_csv('weather_data.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
over100_df = weather_df[weather_df['Humidity'] > 100]
print (over100_df)
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
# N/A

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# N/A - 
#weather_df.drop(weather_df[weather_df['Humidity'] > 100].index, inplace = False)

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Max Temperature (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("LatVsTemp.png")
plt.show()


# The weather becomes significantly warmer the closer we get to the equator (0 Degrees Latitude). 
# On 4/13/2020, the southern hemisphere tends to be warmer than the northern hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Humidity (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("LatVsHum.png")
plt.show()


# Humidity in cities within a range of +/- 19 degrees of the equator appear to be consistently more humid. That said, the 
# relationship between Latitude and Humidity is weak. High and Low humidity appear randomly in both hemispheres outside of the
# +/- 19 degree range.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Cloudiness (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("LatVsCloud.png")
plt.show()

# There is no strong relationship between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Wind Speed (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.ylim(0,50)
plt.grid(True)

plt.savefig("LatVsWndspd.png")
plt.show()

# There is no strong relationship between latitude and wind speed. However, in the northern hemisphere, 
# there are a few cities that have above average (20 mph) windspeeds.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) < 0, :]

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("Strong relationship with Temp and Latitude: Temperature decreases the further north (- lat) you go from the equator.")
plt.show()
# Out:
# Regression line equation is: y = -0.99x + 92.89
# The r-squared is: -0.8876964034562467
# Strong relationship with Temp and Latitude: Temperature decreases the further north (- lat) you go from the equator.

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("Strong relationship with Temp and Latitude: Temperature increases the further south (+lat) you go toward the equator.")
plt.show()
# Out:
# Regression line equation is: y = 0.57x + 83.57
# The r-squared is: 0.6798705066219521
# The regression displays a positive correlation.
# Strong relationship with Temp and Latitude: Temperature increases the further south (+lat) you go toward the equator.

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("This regression suggests a weak correlation between the Latitude and Humidity.") 
plt.show()
# Out:
# Regression line equation is: y = 0.27x + 59.4
# The r-squared is: 0.25058836478907104
# This regression suggests a weak correlation between the Latitude and Humidity.

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("This regression suggests a weak correlation between the Latitude and Humidity.")
plt.show()
# Out:
# Regression line equation is: y = 0.25x + 76.73
# The r-squared is: 0.21005301615328795
# This regression suggests a weak correlation between the Latitude and Humidity.

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("This regression suggests a weak correlation between the Latitude and Cloudiness.")
plt.show()
# Out:
# Regression line equation is: y = 0.37x + 41.04
# The r-squared is: 0.19237837822159204
# This regression suggests a weak correlation between the Latitude and Cloudiness.

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("This regression suggests a weak correlation between the Latitude and Cloudiness.")
plt.show()
# Out:
# Regression line equation is: y = 0.76x + 67.7
# The r-squared is: 0.28840750747786525
# This regression suggests a weak correlation between the Latitude and Cloudiness.

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("This regression suggests a weak correlation between the Latitude and Wind Speed.")
plt.show()
# Out:
# Regression line equation is: y = 0.07x + 5.46
# The r-squared is: 0.2846294293841909
# This regression suggests a weak correlation between the Latitude and Wind Speed.

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("This regression suggests a weak correlation between the Latitude and Wind Speed.")
plt.show()
# Out:
# Regression line equation is: y = -0.13x + 3.57
# The r-squared is: -0.4230670186183112
# This regression suggests a weak correlation between the Latitude and Wind Speed.
