# %% [markdown]
# # WeatherPy
# ----
#
# # This analysis will use Python scripting to visualize the weather of 600+ cities around the world with varying distances from the equator. The script will make external calls to the OpenWeatherMap API.
#
# # Outcomes: Build a series of visualizations (scatter plots) to show the following relationships:
#
#    #    Temperature (F) vs. Latitude
#    #    Humidity (%) vs. Latitude
#    #    Cloudiness (%) vs. Latitude
#    #    Wind Speed (mph) vs. Latitude
#
# # Framework :
#
#   #    Python Requests
#   #    APIs
#   #    JSON Traversals
#
# # Analysis:
#
# # The weather becomes significantly warmer the closer we get to the equator (0 Degrees Latitude). On 4/13/2020, the southern hemisphere tends to be warmer than the northern hemisphere.
#
#
# # Humidity in cities within a range of +/- 19 degrees of the equator appear to be consistently more humid. That said, the relationship between Latitude and Humidity is weak. High and Low humidity appear randomly in both hemispheres outside of the +/- 19 degree range.
#
#
# # There is no strong relationship between latitude and cloudiness.
#
#
# # There is no strong relationship between latitude and wind speed. However, in the northern hemisphere, there are a few cities that have above average (20 mph) windspeeds.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
#print (weather_api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#cities
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#OpenWeather API URL...
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# set up the query URL and make the request
weatherAPI_url = url + "appid=" + weather_api_key + "&units=" + units + "&q="
weatherAPI_response = requests.get(weatherAPI_url + cities[2])
#if weatherAPI_response.status_code == 200:
#    print("yes")

print("Beginning Data Retrival")
print("------------------------------")
group_counter = 1
rec_counter = 1

weather_data = {"City":[],"Lat":[],"Lng":[],"Max Temp":[],"Humidity":[],"Cloudiness":[],
                "Wind Speed":[],"Country":[],"Date":[]}

for city in cities:
    weatherAPI_response = requests.get(weatherAPI_url + city)
    weatherAPI_response_json = weatherAPI_response.json()
    
    if weatherAPI_response.status_code == 200:
        weather_data["City"].append(city)
        weather_data["Cloudiness"].append(weatherAPI_response_json['clouds']['all'])
        weather_data["Country"].append(weatherAPI_response_json['sys']['country'])
        weather_data["Date"].append(weatherAPI_response_json['dt'])
        weather_data["Humidity"].append(weatherAPI_response_json['main']['humidity'])
        weather_data["Lat"].append(weatherAPI_response_json['coord']['lat'])
        weather_data["Lng"].append(weatherAPI_response_json['coord']['lon'])
        weather_data["Max Temp"].append(weatherAPI_response_json['main']['temp_max'])
        weather_data["Wind Speed"].append(weatherAPI_response_json['wind']['speed'])
        if rec_counter <= 50:
            print(f"Processing Record {rec_counter} of Set {group_counter} | {city}")
            rec_counter += 1 
        else:
            rec_counter = 0
            group_counter += 1
            print(f"Processing Record {rec_counter} of Set {group_counter} | {city}")
            rec_counter += 1
    else:
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrival
# ------------------------------
# Processing Record 1 of Set 1 | college
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | kamakwie
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | praia da vitoria
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | zaplavnoye
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | vila velha
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | gwadar
# Processing Record 17 of Set 1 | sembakung
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | changji
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | jibuti
# City not found. Skipping...
# Processing Record 22 of Set 1 | castro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | placido de castro
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | borovoy
# Processing Record 43 of Set 4 | hoshangabad
# Processing Record 44 of Set 4 | bluff
# Processing Record 45 of Set 4 | pa sang
# Processing Record 46 of Set 4 | kongoussi
# Processing Record 47 of Set 4 | svetlogorsk
# City not found. Skipping...
# Processing Record 48 of Set 4 | yar-sale
# Processing Record 49 of Set 4 | inhambane
# Processing Record 50 of Set 4 | yangambi
# Processing Record 0 of Set 5 | kassala
# Processing Record 1 of Set 5 | roi et
# Processing Record 2 of Set 5 | itaueira
# Processing Record 3 of Set 5 | xuddur
# Processing Record 4 of Set 5 | trairi
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | sao raimundo nonato
# Processing Record 7 of Set 5 | bairiki
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | evreux
# Processing Record 10 of Set 5 | meulaboh
# Processing Record 11 of Set 5 | kungurtug
# Processing Record 12 of Set 5 | vila franca do campo
# Processing Record 13 of Set 5 | celaya
# Processing Record 14 of Set 5 | toribio
# Processing Record 15 of Set 5 | ponta do sol
# Processing Record 16 of Set 5 | gat
# Processing Record 17 of Set 5 | takanabe
# City not found. Skipping...
# Processing Record 18 of Set 5 | avera
# Processing Record 19 of Set 5 | viedma
# Processing Record 20 of Set 5 | rapid valley
# Processing Record 21 of Set 5 | port arthur
# Processing Record 22 of Set 5 | seoul
# City not found. Skipping...
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | burnie
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | wabrzezno
# Processing Record 28 of Set 5 | roebourne
# Processing Record 29 of Set 5 | hovd
# Processing Record 30 of Set 5 | chicama
# Processing Record 31 of Set 5 | thio
# Processing Record 32 of Set 5 | baculin
# Processing Record 33 of Set 5 | moree
# Processing Record 34 of Set 5 | biloela
# Processing Record 35 of Set 5 | deputatskiy
# Processing Record 36 of Set 5 | ypsonas
# Processing Record 37 of Set 5 | perth
# Processing Record 38 of Set 5 | caxito
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | tambacounda
# Processing Record 41 of Set 5 | caravelas
# Processing Record 42 of Set 5 | kyra
# Processing Record 43 of Set 5 | margate
# Processing Record 44 of Set 5 | mar del plata
# Processing Record 45 of Set 5 | leningradskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | campinas
# Processing Record 47 of Set 5 | arys
# Processing Record 48 of Set 5 | pisco
# City not found. Skipping...
# Processing Record 49 of Set 5 | ajdabiya
# Processing Record 50 of Set 5 | show low
# Processing Record 0 of Set 6 | broome
# Processing Record 1 of Set 6 | dawei
# Processing Record 2 of Set 6 | san luis
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | ihosy
# Processing Record 5 of Set 6 | gweta
# Processing Record 6 of Set 6 | charleston
# Processing Record 7 of Set 6 | kahului
# City not found. Skipping...
# Processing Record 8 of Set 6 | kulu
# Processing Record 9 of Set 6 | vytegra
# Processing Record 10 of Set 6 | berbera
# Processing Record 11 of Set 6 | laguna
# Processing Record 12 of Set 6 | camana
# Processing Record 13 of Set 6 | coolum beach
# Processing Record 14 of Set 6 | derzhavinsk
# Processing Record 15 of Set 6 | san quintin
# Processing Record 16 of Set 6 | sao joao da barra
# Processing Record 17 of Set 6 | necochea
# Processing Record 18 of Set 6 | fallon
# Processing Record 19 of Set 6 | carutapera
# Processing Record 20 of Set 6 | hokitika
# Processing Record 21 of Set 6 | general roca
# Processing Record 22 of Set 6 | perigueux
# City not found. Skipping...
# Processing Record 23 of Set 6 | manzil kamil
# Processing Record 24 of Set 6 | along
# Processing Record 25 of Set 6 | porto tolle
# Processing Record 26 of Set 6 | rio grande
# Processing Record 27 of Set 6 | anloga
# Processing Record 28 of Set 6 | dossor
# City not found. Skipping...
# Processing Record 29 of Set 6 | lasa
# Processing Record 30 of Set 6 | gorontalo
# Processing Record 31 of Set 6 | kibre mengist
# Processing Record 32 of Set 6 | yellowknife
# Processing Record 33 of Set 6 | ewa beach
# Processing Record 34 of Set 6 | bacolod
# Processing Record 35 of Set 6 | alice springs
# Processing Record 36 of Set 6 | antalaha
# Processing Record 37 of Set 6 | jardim
# Processing Record 38 of Set 6 | pevek
# Processing Record 39 of Set 6 | dombarovskiy
# Processing Record 40 of Set 6 | pangoa
# Processing Record 41 of Set 6 | santa pola
# Processing Record 42 of Set 6 | airai
# Processing Record 43 of Set 6 | darhan
# Processing Record 44 of Set 6 | maragogi
# Processing Record 45 of Set 6 | zabid
# Processing Record 46 of Set 6 | qaqortoq
# Processing Record 47 of Set 6 | clarksburg
# Processing Record 48 of Set 6 | oskarshamn
# Processing Record 49 of Set 6 | dali
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 0 of Set 7 | santarem
# Processing Record 1 of Set 7 | ridgecrest
# Processing Record 2 of Set 7 | garowe
# City not found. Skipping...
# Processing Record 3 of Set 7 | batagay-alyta
# Processing Record 4 of Set 7 | bazarnyy karabulak
# Processing Record 5 of Set 7 | aras
# Processing Record 6 of Set 7 | ponta delgada
# Processing Record 7 of Set 7 | narsaq
# Processing Record 8 of Set 7 | huai thalaeng
# Processing Record 9 of Set 7 | pizarro
# Processing Record 10 of Set 7 | celestun
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 7 | sayyan
# Processing Record 12 of Set 7 | luderitz
# Processing Record 13 of Set 7 | la asuncion
# Processing Record 14 of Set 7 | wilmington
# Processing Record 15 of Set 7 | biak
# Processing Record 16 of Set 7 | jumla
# Processing Record 17 of Set 7 | ahuimanu
# Processing Record 18 of Set 7 | cherskiy
# Processing Record 19 of Set 7 | samarai
# Processing Record 20 of Set 7 | maldonado
# Processing Record 21 of Set 7 | strezhevoy
# Processing Record 22 of Set 7 | chumikan
# Processing Record 23 of Set 7 | drumheller
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 7 | swan river
# City not found. Skipping...
# Processing Record 25 of Set 7 | grindavik
# Processing Record 26 of Set 7 | vanimo
# Processing Record 27 of Set 7 | cravinhos
# Processing Record 28 of Set 7 | flagstaff
# Processing Record 29 of Set 7 | kaeo
# Processing Record 30 of Set 7 | ostrovnoy
# City not found. Skipping...
# Processing Record 31 of Set 7 | mezhdurechenskiy
# Processing Record 32 of Set 7 | imbituba
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 8 | hangu
# Processing Record 45 of Set 8 | basco
# Processing Record 46 of Set 8 | port hardy
# Processing Record 47 of Set 8 | kieta
# Processing Record 48 of Set 8 | araouane
# Processing Record 49 of Set 8 | saint-joseph
# Processing Record 50 of Set 8 | santa fe
# Processing Record 0 of Set 9 | chagoda
# Processing Record 1 of Set 9 | ilulissat
# Processing Record 2 of Set 9 | el tigre
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | barreirinhas
# Processing Record 5 of Set 9 | ixtapa
# Processing Record 6 of Set 9 | mehamn
# Processing Record 7 of Set 9 | swan hill
# Processing Record 8 of Set 9 | ancud
# Processing Record 9 of Set 9 | sobolevo
# City not found. Skipping...
# Processing Record 10 of Set 9 | uttarkashi
# Processing Record 11 of Set 9 | barabinsk
# Processing Record 12 of Set 9 | clyde river
# City not found. Skipping...
# Processing Record 13 of Set 9 | suffolk
# Processing Record 14 of Set 9 | baishishan
# Processing Record 15 of Set 9 | changli
# Processing Record 16 of Set 9 | milan
# Processing Record 17 of Set 9 | kaseda
# Processing Record 18 of Set 9 | slave lake
# Processing Record 19 of Set 9 | sterling
# Processing Record 20 of Set 9 | canyon lake
# Processing Record 21 of Set 9 | macae
# Processing Record 22 of Set 9 | raton
# Processing Record 23 of Set 9 | conde
# Processing Record 24 of Set 9 | sao bernardo
# Processing Record 25 of Set 9 | iquique
# Processing Record 26 of Set 9 | ambatofinandrahana
# City not found. Skipping...
# Processing Record 27 of Set 9 | bodden town
# Processing Record 28 of Set 9 | bonavista
# Processing Record 29 of Set 9 | chemal
# Processing Record 30 of Set 9 | egvekinot
# Processing Record 31 of Set 9 | dolores
# Processing Record 32 of Set 9 | acacoyagua
# Processing Record 33 of Set 9 | santa maria
# Processing Record 34 of Set 9 | ipameri
# Processing Record 35 of Set 9 | bitung
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | jaguey grande
# Processing Record 38 of Set 9 | chengde
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | sault sainte marie
# Processing Record 41 of Set 9 | pavilosta
# Processing Record 42 of Set 9 | tilichiki
# Processing Record 43 of Set 9 | boshnyakovo
# Processing Record 44 of Set 9 | mizdah
# Processing Record 45 of Set 9 | caibarien
# Processing Record 46 of Set 9 | bowen
# Processing Record 47 of Set 9 | half moon bay
# Processing Record 48 of Set 9 | qinzhou
# Processing Record 49 of Set 9 | de aar
# City not found. Skipping...
# Processing Record 50 of Set 9 | bathsheba
# Processing Record 0 of Set 10 | mitsamiouli
# Processing Record 1 of Set 10 | piddig
# Processing Record 2 of Set 10 | talara
# Processing Record 3 of Set 10 | wajir
# Processing Record 4 of Set 10 | allen
# Processing Record 5 of Set 10 | guadix
# Processing Record 6 of Set 10 | ust-maya
# Processing Record 7 of Set 10 | pindorama
# City not found. Skipping...
# Processing Record 8 of Set 10 | abnub
# Processing Record 9 of Set 10 | micheweni
# City not found. Skipping...
# Processing Record 10 of Set 10 | le vauclin
# Processing Record 11 of Set 10 | hami
# Processing Record 12 of Set 10 | berlevag
# Processing Record 13 of Set 10 | aksarka
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 10 | khandyga
# Processing Record 15 of Set 10 | izmir
# Processing Record 16 of Set 10 | pleshanovo
# Processing Record 17 of Set 10 | puerto escondido
# Processing Record 18 of Set 10 | angoche
# Processing Record 19 of Set 10 | sal rei
# Processing Record 20 of Set 10 | kabalo
# Processing Record 21 of Set 10 | husavik
# City not found. Skipping...
# Processing Record 22 of Set 10 | ahome
# Processing Record 23 of Set 10 | ust-donetskiy
# Processing Record 24 of Set 10 | alyangula
# Processing Record 25 of Set 10 | raudeberg
# Processing Record 26 of Set 10 | los lunas
# Processing Record 27 of Set 10 | ranghulu
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | lompoc
# Processing Record 30 of Set 10 | pathein
# Processing Record 31 of Set 10 | dalianwan
# Processing Record 32 of Set 10 | gumdag
# Processing Record 33 of Set 10 | lake charles
# Processing Record 34 of Set 10 | valley city
# Processing Record 35 of Set 10 | charters towers
# City not found. Skipping...
# Processing Record 36 of Set 10 | lahad datu
# Processing Record 37 of Set 10 | madison
# Processing Record 38 of Set 10 | erzin
# Processing Record 39 of Set 10 | kutum
# Processing Record 40 of Set 10 | buala
# Processing Record 41 of Set 10 | guerrero negro
# Processing Record 42 of Set 10 | bati
# Processing Record 43 of Set 10 | asadabad
# Processing Record 44 of Set 10 | pontianak
# Processing Record 45 of Set 10 | matara
# Processing Record 46 of Set 10 | fortuna
# Processing Record 47 of Set 10 | mascote
# Processing Record 48 of Set 10 | mazagao
# Processing Record 49 of Set 10 | taltal
# Processing Record 50 of Set 10 | abong mbang
# Processing Record 0 of Set 11 | lorengau
# Processing Record 1 of Set 11 | anadyr
# Processing Record 2 of Set 11 | cap malheureux
# Processing Record 3 of Set 11 | at-bashi
# Processing Record 4 of Set 11 | magadan
# Processing Record 5 of Set 11 | fort nelson
# Processing Record 6 of Set 11 | ishigaki
# Processing Record 7 of Set 11 | westport
# Processing Record 8 of Set 11 | homun
# Processing Record 9 of Set 11 | moroni
# Processing Record 10 of Set 11 | waipawa
# Processing Record 11 of Set 11 | warrnambool
# Processing Record 12 of Set 11 | qom
# Processing Record 13 of Set 11 | snyder
# Processing Record 14 of Set 11 | umbertide
# Processing Record 15 of Set 11 | acapulco
# Processing Record 16 of Set 11 | tual
# City not found. Skipping...
# Processing Record 17 of Set 11 | atherton
# Processing Record 18 of Set 11 | tura
# Processing Record 19 of Set 11 | balakhta
# Processing Record 20 of Set 11 | port lincoln
# Processing Record 21 of Set 11 | bambanglipuro
# Processing Record 22 of Set 11 | sun city west
# Processing Record 23 of Set 11 | constitucion
# Processing Record 24 of Set 11 | yurimaguas
# Processing Record 25 of Set 11 | sitangkai
# Processing Record 26 of Set 11 | vardo
# Processing Record 27 of Set 11 | mabaruma
# Processing Record 28 of Set 11 | saint-louis
# Processing Record 29 of Set 11 | villafranca de los barros
# Processing Record 30 of Set 11 | portland
# Processing Record 31 of Set 11 | ruwi
# Processing Record 32 of Set 11 | aklavik
# Processing Record 33 of Set 11 | tran
# Processing Record 34 of Set 11 | socastee
# Processing Record 35 of Set 11 | northam
# Processing Record 36 of Set 11 | syasstroy
# Processing Record 37 of Set 11 | troitskoye
# Processing Record 38 of Set 11 | zhangye
# Processing Record 39 of Set 11 | agadez
# Processing Record 40 of Set 11 | ust-tsilma
# City not found. Skipping...
# Processing Record 41 of Set 11 | xining
# Processing Record 42 of Set 11 | severobaykalsk
# Processing Record 43 of Set 11 | sakakah
# Processing Record 44 of Set 11 | araci
# Processing Record 45 of Set 11 | snasa
# Processing Record 46 of Set 11 | topeka
# City not found. Skipping...
# Processing Record 47 of Set 11 | srednekolymsk
# Processing Record 48 of Set 11 | isla mujeres
# City not found. Skipping...
# Processing Record 49 of Set 11 | sandwick
# Processing Record 50 of Set 11 | kibala
# Processing Record 0 of Set 12 | chatakonda
# Processing Record 1 of Set 12 | senador jose porfirio
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | reserva
# Processing Record 4 of Set 12 | gotsu
# Processing Record 5 of Set 12 | okitipupa
# Processing Record 6 of Set 12 | shimoda
# Processing Record 7 of Set 12 | hervey bay
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(weather_data)
weather_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      college  64.86 -147.80     39.99        80          90        2.75
# 1      rikitea -23.12 -134.97     76.86        65          53        5.21
# 2  port alfred -33.59   26.89     64.99        89          28        3.00
# 3     kamakwie   9.50  -12.23     96.10        37          38        7.23
# 4    busselton -33.65  115.33     53.01        92          71        8.37
#
#   Country        Date
# 0      US  1587144794
# 1      PF  1587144794
# 2      ZA  1587144794
# 3      SL  1587144794
# 4      AU  1587144795

# %%
# Exporting the city data into csv
weather_df.to_csv('weather_data.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
over100_df = weather_df[weather_df['Humidity'] > 100]
print (over100_df)
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
# N/A

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# N/A - 
#weather_df.drop(weather_df[weather_df['Humidity'] > 100].index, inplace = False)

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Max Temperature (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("LatVsTemp.png")
plt.show()


# The weather becomes significantly warmer the closer we get to the equator (0 Degrees Latitude). 
# On 4/13/2020, the southern hemisphere tends to be warmer than the northern hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Humidity (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("LatVsHum.png")
plt.show()


# Humidity in cities within a range of +/- 19 degrees of the equator appear to be consistently more humid. That said, the 
# relationship between Latitude and Humidity is weak. High and Low humidity appear randomly in both hemispheres outside of the
# +/- 19 degree range.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Cloudiness (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("LatVsCloud.png")
plt.show()

# There is no strong relationship between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Wind Speed (04/13/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.ylim(0,50)
plt.grid(True)

plt.savefig("LatVsWndspd.png")
plt.show()

# There is no strong relationship between latitude and wind speed. However, in the northern hemisphere, 
# there are a few cities that have above average (20 mph) windspeeds.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
